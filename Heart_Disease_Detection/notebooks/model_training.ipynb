# %% [markdown]
# # Heart Disease Model Training
#
# This notebook trains the decision tree classifier, evaluates it, and compares it to the rule-based expert system.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from ml_model.train_model import train_and_evaluate

# %%
results = train_and_evaluate()
results['model_metrics']

# %%
results['rule_metrics']

# %%
results['best_params']
